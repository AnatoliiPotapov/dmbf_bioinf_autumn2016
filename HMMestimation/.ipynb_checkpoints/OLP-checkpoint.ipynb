# %%
import numpy as np

# %%
with open('input.txt') as f:
    lines = f.readlines()

lines = [line.replace("\t", " ").replace("\n", "") for line in lines]
# print lines

# %%
# parsing data

l_obs = lines[0]
obs_alph = lines[2].split(" ")
hid_alph = lines[4].split(" ")

# print obs_alph

alph_obs = {}
for ind,el in enumerate(obs_alph):
    if el!="":
        alph_obs[el] = ind


alph_hid = {}
for ind,el in enumerate(hid_alph):
    if el!="":
        alph_hid[el] = ind 

def read_matrix(lines, start, n, last = False):
    m = []
    for i in range(n):
        if last == True and i == n-1:
            m.append(lines[start + i].replace("\n","").split(" ")[1:])
        else:
            m.append(lines[start + i].replace("\n","").split(" ")[1:-1])
    return m

tr_prob = read_matrix(lines, 7, len(alph_hid))
tr_emission = read_matrix(lines, 7 + 2 + len(alph_hid), len(alph_hid), last = True)

# print tr_prob, tr_emission

# %%
# инициализируем скрытую марковскую модель

class HMM(object):
    
    alph_hidden = {}
    alph_viz = {}
    
    tr_m = []
    em_m = []
    
    def __init__(self, alph_hidden, alph_viz, tr_prob, tr_emission):
        
        self.alph_hidden = alph_hidden
        self.alph_viz = alph_viz
        
        self.tr_m = np.array(tr_prob).astype(np.float)
        self.em_m = np.array(tr_emission).astype(np.float)
    
    # для пары скрытых состояний возвращает вероятность шифта
    def get_tr_p(self, ch1, ch2):
        return self.tr_m[ch1, ch2]
    
    # для данного скрытого и видимого состояния возвращает вероятность эмиссии
    def get_em_p(self, hid, viz):
        return self.em_m[hid, self.alph_viz[viz]]
    
Hmm = HMM(alph_hid, alph_obs, tr_prob, tr_emission)

# print Hmm.alph_hidden
# print Hmm.alph_viz

# %%
# Viterbi algorithm implementation

def get_path(Hmm, in_str):
    
    # t - длина входной строки
    t = len(in_str)
    # k - размер алфавита наблюдаемых состояний
    k = len(Hmm.alph_viz)
    # h - размер алфавита скрытых состояний
    h = len(Hmm.alph_hidden)
    
    # score - максимум произведения весов по всем путям из начала до данной вершины
    score = np.zeros((h,t))
    # index - путь, соответствующий наибольшему score
    index = np.zeros((h,t))
    
    score[:,0] = np.array([Hmm.get_em_p(st,in_str[0]) for st in range(h)])
    # print score
    
    forward = np.zeros((h,t))
    
    print Hmm.em_m
    for i in range(t)[1:]:
        for st in range(h):
            pre_sc = [score[ind, i-1] + np.log(Hmm.get_tr_p(st,ind)) + np.log(Hmm.get_em_p(st,in_str[i])) for ind in range(h)]
            pre_sc_i = [score[ind, i-1] + np.log(Hmm.get_tr_p(st,ind)) for ind in range(h)]

            score[st, i] = np.max(pre_sc)
            index[st, i] = np.argmax(pre_sc_i)
    
    
    # print score
    # print index
    
    # обратный ход алгоритма
    v_path = np.zeros(t)
    v_path[t-1] = np.argmax(score[:,t-1])
    
    for i in range(t)[1:][::-1]:
        v_path[i - 1] = index[v_path[i], i]

    rev_d = dict(zip(Hmm.alph_hidden.values(),Hmm.alph_hidden.keys()))    
    
    # print [rev_d[state] for state in v_path]
    return [rev_d[state] for state in v_path]

output = get_path(Hmm, l_obs)
# Out:
# [0.0033000000000000004, 0.135907]
# [0.0033000000000000004, 0.135907]
# [0.0, 0.018919205748999999]
# [0.0, 0.018919205748999999]
# [0.0, 0.002571252495729343]
# [0.0, 0.002571252495729343]
# [0.0, 0.00036068758634342504]
# [0.0, 0.00036068758634342504]
# [0.0, 5.8004334885404247e-05]
# [0.0, 5.8004334885404247e-05]
# [0.0, 9.3280251189311689e-06]
# [0.0, 9.3280251189311689e-06]
# [0.0, 1.2677439098385784e-06]
# [0.0, 1.2677439098385784e-06]
# [0.0, 2.0387350460460083e-07]
# [0.0, 2.0387350460460083e-07]
# [0.0, 2.8598763605419589e-08]
# [0.0, 2.8598763605419589e-08]
# [0.0, 4.599138767969157e-09]
# [0.0, 4.599138767969157e-09]
# [0.0, 6.2505515253838415e-10]
# [0.0, 6.2505515253838415e-10]
# [0.0, 1.0051886941061277e-10]
# [0.0, 1.0051886941061277e-10]
# [0.0, 1.6165042503137104e-11]
# [0.0, 1.6165042503137104e-11]
# [0.0, 2.1969424314738543e-12]
# [0.0, 2.1969424314738543e-12]
# [0.0, 3.0818049345985791e-13]
# [0.0, 3.0818049345985791e-13]
# [0.0, 4.3230635081068485e-14]
# [0.0, 4.3230635081068485e-14]
# [0.0, 5.8753459219627745e-15]
# [0.0, 5.8753459219627745e-15]
# [0.0, 8.2417589989517218e-16]
# [0.0, 8.2417589989517218e-16]
# [0.0, 1.3254067151754201e-16]
# [0.0, 1.3254067151754201e-16]
# [0.0, 2.1314660630765033e-17]
# [0.0, 2.1314660630765033e-17]
# [0.0, 2.8968115823453831e-18]
# [0.0, 2.8968115823453831e-18]
# [0.0, 4.0635603833666333e-19]
# [0.0, 4.0635603833666333e-19]
# [0.0, 5.7002405989752127e-20]
# [0.0, 5.7002405989752127e-20]
# [0.0, 7.747025990849242e-21]
# [0.0, 7.747025990849242e-21]
# [0.0, 1.2458457317444117e-21]
# [0.0, 1.2458457317444117e-21]
# [0.0, 1.6931915586418777e-22]
# [0.0, 1.6931915586418777e-22]
# [0.0, 2.3011658516034165e-23]
# [0.0, 2.3011658516034165e-23]
# [0.0, 3.2280064216537248e-24]
# [0.0, 3.2280064216537248e-24]
# [0.0, 5.1911508070466539e-25]
# [0.0, 5.1911508070466539e-25]
# [0.0, 7.2819906176008358e-26]
# [0.0, 7.2819906176008358e-26]
# [0.0, 1.0214957978651924e-26]
# [0.0, 1.0214957978651924e-26]
# [0.0, 1.6427286822948878e-27]
# [0.0, 1.6427286822948878e-27]
# [0.0, 2.3043705136627999e-28]
# [0.0, 2.3043705136627999e-28]
# [0.0, 3.7057964852519681e-29]
# [0.0, 3.7057964852519681e-29]
# [0.0, 5.1983801356169033e-30]
# [0.0, 5.1983801356169033e-30]
# [0.0, 7.2921317028393232e-31]
# [0.0, 7.2921317028393232e-31]
# [0.0, 1.1726914519238085e-31]
# [0.0, 1.1726914519238085e-31]
# [0.0, 1.5937697715660905e-32]
# [0.0, 1.5937697715660905e-32]
# [0.0, 2.1660446834423269e-33]
# [0.0, 2.1660446834423269e-33]
# [0.0, 3.4833464181246123e-34]
# [0.0, 3.4833464181246123e-34]
# [0.0, 4.8863338549526626e-35]
# [0.0, 4.8863338549526626e-35]
# [0.0, 6.6408697522505158e-36]
# [0.0, 6.6408697522505158e-36]
# [0.0, 9.0254068541911085e-37]
# [0.0, 9.0254068541911085e-37]
# [0.0, 1.2660569972853663e-37]
# [0.0, 1.2660569972853663e-37]
# [0.0, 2.0360222207544345e-38]
# [0.0, 2.0360222207544345e-38]
# [0.0, 2.7670967195607292e-39]
# [0.0, 2.7670967195607292e-39]
# [0.0, 3.7606781386533999e-40]
# [0.0, 3.7606781386533999e-40]
# [0.0, 5.2753664725588299e-41]
# [0.0, 5.2753664725588299e-41]
# [0.0, 7.1695923118605285e-42]
# [0.0, 7.1695923118605285e-42]
# [0.0, 9.7439778232802883e-43]
# [0.0, 9.7439778232802883e-43]
# [0.0, 1.5669875376286427e-43]
# [0.0, 1.5669875376286427e-43]
# [0.0, 2.1981231081593313e-44]
# [0.0, 2.1981231081593313e-44]
# [0.0, 3.0834611524326656e-45]
# [0.0, 3.0834611524326656e-45]
# [0.0, 4.3253868007979704e-46]
# [0.0, 4.3253868007979704e-46]
# [0.0, 6.0675228425553696e-47]
# [0.0, 6.0675228425553696e-47]
# [0.0, 8.511339017851396e-48]
# [0.0, 8.511339017851396e-48]
# [0.0, 1.1939451034071403e-48]
# [0.0, 1.1939451034071403e-48]
# [0.0, 1.6748303727064342e-49]
# [0.0, 1.6748303727064342e-49]
# [0.0, 2.2762117146341333e-50]
# [0.0, 2.2762117146341333e-50]
# [0.0, 3.6605126310060277e-51]
# [0.0, 3.6605126310060277e-51]
# [0.0, 5.1348573033963252e-52]
# [0.0, 5.1348573033963252e-52]
# [0.0, 8.2576721210298348e-53]
# [0.0, 8.2576721210298348e-53]
# [0.0, 1.1222754449528019e-53]
# [0.0, 1.1222754449528019e-53]
# [0.0, 1.5742943259164422e-54]
# [0.0, 1.5742943259164422e-54]
# [0.0, 2.2083728515658076e-55]
# [0.0, 2.2083728515658076e-55]
# [0.0, 3.5514168849740692e-56]
# [0.0, 3.5514168849740692e-56]
# [0.0, 4.8266241458617085e-57]
# [0.0, 4.8266241458617085e-57]
# [0.0, 6.7706435530904287e-58]
# [0.0, 6.7706435530904287e-58]
# [0.0, 9.4976556569686614e-59]
# [0.0, 9.4976556569686614e-59]
# [0.0, 1.5273749921310723e-59]
# [0.0, 1.5273749921310723e-59]
# [0.0, 2.1425558177117043e-60]
# [0.0, 2.1425558177117043e-60]
# [0.0, 2.9118833351774462e-61]
# [0.0, 2.9118833351774462e-61]
# [0.0, 4.6827743042989622e-62]
# [0.0, 4.6827743042989622e-62]
# [0.0, 7.5306503252014185e-63]
# [0.0, 7.5306503252014185e-63]
# [0.0, 1.2110490626975913e-63]
# [0.0, 1.2110490626975913e-63]
# [0.0, 1.9475606606677585e-64]
# [0.0, 1.9475606606677585e-64]
# [0.0, 3.1319891520594623e-65]
# [0.0, 3.1319891520594623e-65]
# [0.0, 4.2565924968894531e-66]
# [0.0, 4.2565924968894531e-66]
# [0.0, 5.9710202568616182e-67]
# [0.0, 5.9710202568616182e-67]
# [0.0, 8.3759680857177721e-68]
# [0.0, 8.3759680857177721e-68]
# [0.0, 1.1749556751602319e-68]
# [0.0, 1.1749556751602319e-68]
# [0.0, 1.8895167185656786e-69]
# [0.0, 1.8895167185656786e-69]
# [0.0, 2.6505573673023771e-70]
# [0.0, 2.6505573673023771e-70]
# [0.0, 3.6022930011796413e-71]
# [0.0, 3.6022930011796413e-71]
# [0.0, 4.8957683491132154e-72]
# [0.0, 4.8957683491132154e-72]
# [0.0, 7.8731788283099085e-73]
# [0.0, 7.8731788283099085e-73]
# [0.0, 1.2661331264534863e-73]
# [0.0, 1.2661331264534863e-73]
# [0.0, 2.0361446486374383e-74]
# [0.0, 2.0361446486374383e-74]
# [0.0, 2.8562426287691394e-75]
# [0.0, 2.8562426287691394e-75]
# [0.0, 3.8818336694812745e-76]
# [0.0, 3.8818336694812745e-76]
# [0.0, 6.2426096339130058e-77]
# [0.0, 6.2426096339130058e-77]
# [0.0, 1.0039115108873539e-77]
# [0.0, 1.0039115108873539e-77]
# [0.0, 1.364386017101676e-78]
# [0.0, 1.364386017101676e-78]
# [0.0, 2.1941510172622314e-79]
# [0.0, 2.1941510172622314e-79]
# [0.0, 3.07788922248494e-80]
# [0.0, 3.07788922248494e-80]
# [0.0, 4.9497383320313815e-81]
# [0.0, 4.9497383320313815e-81]
# [0.0, 7.9599711960395852e-82]
# [0.0, 7.9599711960395852e-82]
# [0.0, 1.0818158053401518e-82]
# [0.0, 1.0818158053401518e-82]
# [0.0, 1.5175387572570049e-83]
# [0.0, 1.5175387572570049e-83]
# [[  1.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  1.00000000e+00   1.39207000e-01   1.89192057e-02   2.57125250e-03
#     3.60687586e-04   5.80043349e-05   9.32802512e-06   1.26774391e-06
#     2.03873505e-07   2.85987636e-08   4.59913877e-09   6.25055153e-10
#     1.00518869e-10   1.61650425e-11   2.19694243e-12   3.08180493e-13
#     4.32306351e-14   5.87534592e-15   8.24175900e-16   1.32540672e-16
#     2.13146606e-17   2.89681158e-18   4.06356038e-19   5.70024060e-20
#     7.74702599e-21   1.24584573e-21   1.69319156e-22   2.30116585e-23
#     3.22800642e-24   5.19115081e-25   7.28199062e-26   1.02149580e-26
#     1.64272868e-27   2.30437051e-28   3.70579649e-29   5.19838014e-30
#     7.29213170e-31   1.17269145e-31   1.59376977e-32   2.16604468e-33
#     3.48334642e-34   4.88633385e-35   6.64086975e-36   9.02540685e-37
#     1.26605700e-37   2.03602222e-38   2.76709672e-39   3.76067814e-40
#     5.27536647e-41   7.16959231e-42   9.74397782e-43   1.56698754e-43
#     2.19812311e-44   3.08346115e-45   4.32538680e-46   6.06752284e-47
#     8.51133902e-48   1.19394510e-48   1.67483037e-49   2.27621171e-50
#     3.66051263e-51   5.13485730e-52   8.25767212e-53   1.12227544e-53
#     1.57429433e-54   2.20837285e-55   3.55141688e-56   4.82662415e-57
#     6.77064355e-58   9.49765566e-59   1.52737499e-59   2.14255582e-60
#     2.91188334e-61   4.68277430e-62   7.53065033e-63   1.21104906e-63
#     1.94756066e-64   3.13198915e-65   4.25659250e-66   5.97102026e-67
#     8.37596809e-68   1.17495568e-68   1.88951672e-69   2.65055737e-70
#     3.60229300e-71   4.89576835e-72   7.87317883e-73   1.26613313e-73
#     2.03614465e-74   2.85624263e-75   3.88183367e-76   6.24260963e-77
#     1.00391151e-77   1.36438602e-78   2.19415102e-79   3.07788922e-80
#     4.94973833e-81   7.95997120e-82   1.08181581e-82   1.51753876e-83]]

# %%
# writing output to file
with open('output.txt', 'w') as f:
    f.write(''.join(output))

# %%
print ''.join(output)
# Out:
# BBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBB
